# %% [markdown]
# # UC-XXXX-XXXX · Use-Case PoC
#
# PoC for UC-XXXX-XXXX · PLANT · process — proof-of-concept, not production data.
#
# Cookiecutter Data Science layout — raw data in `data/raw/`, reusable code in the
# `analysis` package, this exploratory notebook in `notebooks/`.

# %%
from analysis.dataset import load_raw
from analysis import plots

df = load_raw()
df.head()

# %% [markdown]
# ## Trend

# %%
plots.trend(df)

# %% [markdown]
# ## By line

# %%
plots.by_category(df)

# %% [markdown]
# ## Finding
#
# _State whether the signal is computable and worth a pilot. Success/kill criteria are in `poc/spec.md`._
